# %%
# !pip install openai

# %%
from openai import OpenAI

api_key="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"
client = OpenAI(api_key=api_key)

# List all models
response = client.models.list()

for model in response.data:
    print(model.id)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[1], line 7
#       3 api_key="your-api-key"
#       4 client = OpenAI(api_key=api_key)
#       5
#       6 # List all models
# ----> 7 response = client.models.list()
#       8
#       9 for model in response.data:
#      10     print(model.id)
#
# File c:\Users\KRESHAN88\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\resources\models.py:98, in Models.list(self, extra_headers, extra_query, extra_body, timeout)
#      84 def list(
#      85     self,
#      86     *,
#    (...)     92     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#      93 ) -> SyncPage[Model]:
#      94     """
#      95     Lists the currently available models, and provides basic information about each
#      96     one such as the owner and availability.
#      97     """
# ---> 98     return self._get_api_list(
# ...

# %%
api_key="your-api-key"

# %%
from openai import OpenAI

client = OpenAI(api_key=api_key)

# %%
msgs=[
        {"role": "user", "content": "Tell me a very short, simple story."},

    ]

response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=msgs
)

print(response.choices[0].message.content)
# Out:
# One sunny day, a small mouse found a lost hat. He searched the village with a beetle’s help and found a girl who had dropped it. The girl smiled and shared her cheese to say thanks.

# %%
# msgs = [
#     {"role": "user", "content": "Tell me a very short, simple story."},
# ]

# response = client.chat.completions.create(
#     model="gpt-5-nano",
#     messages=msgs,
#     max_completion_tokens=100,     # maximum tokens in the generated response
#     temperature=0.0,    # randomness: 0 = deterministic, higher = more creative
#     top_p=0.9,          # nucleus sampling
# )

# print(response.choices[0].message.content)

# %%
msgs = [
    {"role": "user", "content": "Tell me a very short, simple story."},
]

response = client.chat.completions.create(
    model="gpt-4o",
    messages=msgs,
    max_completion_tokens=100,     # maximum tokens in the generated response
    temperature=0.0,    # randomness: 0 = deterministic, higher = more creative
    top_p=0.9,          # nucleus sampling
)

print(response.choices[0].message.content)
# Out:
# Once upon a time, in a small village, there was a kind baker named Emma. Every morning, she baked the most delicious bread and shared it with her neighbors. One day, a little bird with a broken wing landed on her windowsill. Emma gently cared for the bird, feeding it crumbs and keeping it warm. As the bird healed, it sang beautiful songs that filled the village with joy. When the bird was strong enough to fly, it circled above Emma's bakery, singing a

# %%
msgs=[
    {"role": "system", "content": "You are a witty assistant and respond only in the style of a pirate."},
    {"role": "user", "content": "Hello! What is the capital of France?"},
    {"role": "assistant", "content": "Ahoy there, matey! Paris be the treasure o' France!"},
    {"role": "user", "content": "what i asked or told you before?"}

]

response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=msgs
)

print(response.choices[0].message.content)
# Out:
# Arrr, here’s the recap, cap’n:
#
# - First message: "Hello! What is the capital of France?" I answered: Paris.
# - Before that, ye only tossed a friendly hello—nothin’ else to tell me what to do.
#
# That be the sum o’ ye past talk, aye. What be yer next command, matey?
