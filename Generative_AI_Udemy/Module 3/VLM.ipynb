# %%
from openai import OpenAI
import base64
import os

api_key="your-api-key"

client = OpenAI(api_key=api_key)

# %%
client = OpenAI(api_key=api_key)
image_path = "data.png"

# A function to encode the image to base64
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

base64_image = encode_image(image_path)

msgs = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "Describe what you see in this image."},
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/png;base64,{base64_image}"
                }
            }
        ],
    }
]

try:
    response = client.chat.completions.create(
        model="gpt-4o",
        messages=msgs,
        max_tokens=300
    )
    print(response.choices[0].message.content)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# The image is an infographic about GDPR, the General Data Protection Regulation. On the left, there's an illustration of a person using a laptop, surrounded by icons representing data privacy elements like a shopping cart, a house, a money bag with a Euro symbol, and a location pin, all connected with dotted lines. The background is blue with stars, resembling the European Union flag.
#
# On the right, there is text saying:
#
# "General Data Protection Regulation (GDPR)
#
# Guidelines for the collection and processing of personal data of individuals within the European Union."
#
# The Investopedia logo is at the bottom.

# %%
client = OpenAI(api_key=api_key)
image_path = "data.png"

# A function to encode the image to base64
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

base64_image = encode_image(image_path)

msgs = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "Extract the texts in structured json format"},
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/png;base64,{base64_image}"
                }
            }
        ],
    }
]

try:
    response = client.chat.completions.create(
        model="gpt-4o",
        messages=msgs,
        max_tokens=300
    )
    print(response.choices[0].message.content)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# ```json
# {
#   "title": "General Data Protection Regulation (GDPR)",
#   "pronunciation": "[ˈjen-rəl ˈdā-tə prə-ˈtek-shən ,re-gyə-ˈlā-shən]",
#   "description": "Guidelines for the collection and processing of personal data of individuals within the European Union.",
#   "source": "Investopedia"
# }
# ```
